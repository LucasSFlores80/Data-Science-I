# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasSFlores80/Data-Science-I/blob/main/An%C3%A1lisis_de_Riesgos_de_muerte_respecto_a_diferentes_factores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/LucasSFlores80/Data-Science-I/main/number-of-deaths-by-risk-factor.csv'
data_2 = pd.read_csv(url, index_col=0)
data_2
# Out:
#             Code  Year  \
# Entity
# Afghanistan  AFG  1990
# Afghanistan  AFG  1991
# Afghanistan  AFG  1992
# Afghanistan  AFG  1993
# Afghanistan  AFG  1994
# ...          ...   ...
# Zimbabwe     ZWE  2015
# Zimbabwe     ZWE  2016
# Zimbabwe     ZWE  2017
# Zimbabwe     ZWE  2018
# Zimbabwe     ZWE  2019
#
#              Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               3169
# Afghanistan                                               3222
# Afghanistan                                               3395
# Afghanistan                                               3623
# Afghanistan                                               3788
# ...                                                        ...
# Zimbabwe                                                  2835
# Zimbabwe                                                  2781
# Zimbabwe                                                  2700
# Zimbabwe                                                  2669
# Zimbabwe                                                  2680
#
#              Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                              25633
# Afghanistan                                              25872
# Afghanistan                                              26309
# Afghanistan                                              26961
# Afghanistan                                              27658
# ...                                                        ...
# Zimbabwe                                                 11483
# Zimbabwe                                                 11663
# Zimbabwe                                                 11819
# Zimbabwe                                                 12002
# Zimbabwe                                                 12241
#
#              Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               1045
# Afghanistan                                               1055
# Afghanistan                                               1075
# Afghanistan                                               1103
# Afghanistan                                               1134
# ...                                                        ...
# Zimbabwe                                                  1063
# Zimbabwe                                                  1082
# Zimbabwe                                                  1098
# Zimbabwe                                                  1117
# Zimbabwe                                                  1140
#
#              Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               7077
# Afghanistan                                               7149
# Afghanistan                                               7297
# Afghanistan                                               7499
# Afghanistan                                               7698
# ...                                                        ...
# Zimbabwe                                                  1354
# Zimbabwe                                                  1383
# Zimbabwe                                                  1409
# Zimbabwe                                                  1439
# Zimbabwe                                                  1475
#
#              Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                356
# Afghanistan                                                364
# Afghanistan                                                376
# Afghanistan                                                389
# Afghanistan                                                399
# ...                                                        ...
# Zimbabwe                                                  4854
# Zimbabwe                                                  4915
# Zimbabwe                                                  4992
# Zimbabwe                                                  5044
# Zimbabwe                                                  5156
#
#              Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               3185
# Afghanistan                                               3248
# Afghanistan                                               3351
# Afghanistan                                               3480
# Afghanistan                                               3610
# ...                                                        ...
# Zimbabwe                                                  1820
# Zimbabwe                                                  1854
# Zimbabwe                                                  1883
# Zimbabwe                                                  1917
# Zimbabwe                                                  1960
#
#              Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               3702
# Afghanistan                                               4309
# Afghanistan                                               5356
# Afghanistan                                               7152
# Afghanistan                                               7192
# ...                                                        ...
# Zimbabwe                                                  4336
# Zimbabwe                                                  4244
# Zimbabwe                                                  4193
# Zimbabwe                                                  4013
# Zimbabwe                                                  3914
#
#              Deaths - Cause: All causes - Risk: Secondhand smoke - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               4794
# Afghanistan                                               4921
# Afghanistan                                               5279
# Afghanistan                                               5734
# Afghanistan                                               6050
# ...                                                        ...
# Zimbabwe                                                  1614
# Zimbabwe                                                  1625
# Zimbabwe                                                  1625
# Zimbabwe                                                  1628
# Zimbabwe                                                  1646
#
#              ...  \
# Entity       ...
# Afghanistan  ...
# Afghanistan  ...
# Afghanistan  ...
# Afghanistan  ...
# Afghanistan  ...
# ...          ...
# Zimbabwe     ...
# Zimbabwe     ...
# Zimbabwe     ...
# Zimbabwe     ...
# Zimbabwe     ...
#
#              Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               9518
# Afghanistan                                               9489
# Afghanistan                                               9528
# Afghanistan                                               9611
# Afghanistan                                               9675
# ...                                                        ...
# Zimbabwe                                                  5636
# Zimbabwe                                                  5849
# Zimbabwe                                                  6047
# Zimbabwe                                                  6248
# Zimbabwe                                                  6475
#
#              Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               2798
# Afghanistan                                               3254
# Afghanistan                                               4042
# Afghanistan                                               5392
# Afghanistan                                               5418
# ...                                                        ...
# Zimbabwe                                                  2879
# Zimbabwe                                                  2798
# Zimbabwe                                                  2744
# Zimbabwe                                                  2608
# Zimbabwe                                                  2531
#
#              Deaths - Cause: All causes - Risk: No access to handwashing facility - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               4825
# Afghanistan                                               5127
# Afghanistan                                               5889
# Afghanistan                                               7007
# Afghanistan                                               7421
# ...                                                        ...
# Zimbabwe                                                  4328
# Zimbabwe                                                  4295
# Zimbabwe                                                  4251
# Zimbabwe                                                  4153
# Zimbabwe                                                  4113
#
#              Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                174
# Afghanistan                                                188
# Afghanistan                                                211
# Afghanistan                                                232
# Afghanistan                                                247
# ...                                                        ...
# Zimbabwe                                                  1068
# Zimbabwe                                                  1042
# Zimbabwe                                                  1007
# Zimbabwe                                                   969
# Zimbabwe                                                   963
#
#              Deaths - Cause: All causes - Risk: Low bone mineral density - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                389
# Afghanistan                                                389
# Afghanistan                                                393
# Afghanistan                                                411
# Afghanistan                                                413
# ...                                                        ...
# Zimbabwe                                                   407
# Zimbabwe                                                   415
# Zimbabwe                                                   424
# Zimbabwe                                                   434
# Zimbabwe                                                   438
#
#              Deaths - Cause: All causes - Risk: Vitamin A deficiency - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               2016
# Afghanistan                                               2056
# Afghanistan                                               2100
# Afghanistan                                               2316
# Afghanistan                                               2665
# ...                                                        ...
# Zimbabwe                                                   138
# Zimbabwe                                                   101
# Zimbabwe                                                    82
# Zimbabwe                                                    85
# Zimbabwe                                                    81
#
#              Deaths - Cause: All causes - Risk: Child stunting - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               7686
# Afghanistan                                               7886
# Afghanistan                                               8568
# Afghanistan                                               9875
# Afghanistan                                              11031
# ...                                                        ...
# Zimbabwe                                                   730
# Zimbabwe                                                   674
# Zimbabwe                                                   629
# Zimbabwe                                                   607
# Zimbabwe                                                   585
#
#              Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                107
# Afghanistan                                                121
# Afghanistan                                                150
# Afghanistan                                                204
# Afghanistan                                                204
# ...                                                        ...
# Zimbabwe                                                    21
# Zimbabwe                                                    20
# Zimbabwe                                                    19
# Zimbabwe                                                    17
# Zimbabwe                                                    16
#
#              Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               2216
# Afghanistan                                               2501
# Afghanistan                                               3053
# Afghanistan                                               3726
# Afghanistan                                               3833
# ...                                                        ...
# Zimbabwe                                                   734
# Zimbabwe                                                   700
# Zimbabwe                                                   678
# Zimbabwe                                                   644
# Zimbabwe                                                   631
#
#              Deaths - Cause: All causes - Risk: Iron deficiency - Sex: Both - Age: All Ages (Number)
# Entity
# Afghanistan                                                564
# Afghanistan                                                611
# Afghanistan                                                700
# Afghanistan                                                773
# Afghanistan                                                812
# ...                                                        ...
# Zimbabwe                                                   282
# Zimbabwe                                                   275
# Zimbabwe                                                   267
# Zimbabwe                                                   261
# Zimbabwe                                                   259
#
# [6840 rows x 30 columns]

# %%
# Analizo la información de las columnas. Los nombres de las variables y de que tipo de dato se trata
data_2 .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6840 entries, Afghanistan to Zimbabwe
# Data columns (total 30 columns):
#  #   Column                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                            --------------  -----
#  0   Code                                                                                                              6150 non-null   object
#  1   Year                                                                                                              6840 non-null   int64
#  2   Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)              6840 non-null   int64
#  3   Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)              6840 non-null   int64
#  4   Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)                       6840 non-null   int64
#  5   Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)                  6840 non-null   int64
#  6   Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)                               6840 non-null   int64
#  7   Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)                        6840 non-null   int64
#  8   Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: All Ages (Number)                       6840 non-null   int64
#  9   Deaths - Cause: All causes - Risk: Secondhand smoke - Sex: Both - Age: All Ages (Number)                          6840 non-null   int64
#  10  Deaths - Cause: All causes - Risk: Low birth weight - Sex: Both - Age: All Ages (Number)                          6840 non-null   int64
#  11  Deaths - Cause: All causes - Risk: Child wasting - Sex: Both - Age: All Ages (Number)                             6840 non-null   int64
#  12  Deaths - Cause: All causes - Risk: Unsafe sex - Sex: Both - Age: All Ages (Number)                                6840 non-null   int64
#  13  Deaths - Cause: All causes - Risk: Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)                6840 non-null   int64
#  14  Deaths - Cause: All causes - Risk: Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)  6840 non-null   int64
#  15  Deaths - Cause: All causes - Risk: Diet low in vegetables - Sex: Both - Age: All Ages (Number)                    6840 non-null   int64
#  16  Deaths - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)                     6840 non-null   int64
#  17  Deaths - Cause: All causes - Risk: Smoking - Sex: Both - Age: All Ages (Number)                                   6840 non-null   int64
#  18  Deaths - Cause: All causes - Risk: High fasting plasma glucose - Sex: Both - Age: All Ages (Number)               6840 non-null   int64
#  19  Deaths - Cause: All causes - Risk: Air pollution - Sex: Both - Age: All Ages (Number)                             6840 non-null   int64
#  20  Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)                      6840 non-null   int64
#  21  Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: All Ages (Number)                         6840 non-null   int64
#  22  Deaths - Cause: All causes - Risk: No access to handwashing facility - Sex: Both - Age: All Ages (Number)         6840 non-null   int64
#  23  Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)                                  6840 non-null   int64
#  24  Deaths - Cause: All causes - Risk: Low bone mineral density - Sex: Both - Age: All Ages (Number)                  6840 non-null   int64
#  25  Deaths - Cause: All causes - Risk: Vitamin A deficiency - Sex: Both - Age: All Ages (Number)                      6840 non-null   int64
#  26  Deaths - Cause: All causes - Risk: Child stunting - Sex: Both - Age: All Ages (Number)                            6840 non-null   int64
#  27  Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)                6840 non-null   int64
#  28  Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)               6840 non-null   int64
#  29  Deaths - Cause: All causes - Risk: Iron deficiency - Sex: Both - Age: All Ages (Number)                           6840 non-null   int64
# dtypes: int64(29), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Sería recomendable cambiar el índice de las columnas ya que se trata de nombres extensos. Para ello se establece:
#
# 0 = COD (Código)
#
# 1 = AÑO (Año)
#
# 2 = CAE (Contaminación aire exterior)
#
# 3 = HIP (Hipertensión)
#
# 4 = DAS (Dieta alta en sodio)
#
# 5 = DBG (Dieta baja en granos)
#
# 6 = ALC (Alcoholismo)
#
# 7 = DBF (Dieta baja en frutas)
#
# 8 = AGI (Agua insalubre)
#
# 9 = FUP (Fumador pasivo)
#
# 10 = BPN (Bajo peso al nacer)
#
# 11 = DEI (Desnutrición infantil)
#
# 12 = SXI (Sexo inseguro)
#
# 13 = DBS (Dieta baja en semillas)
#
# 14 = ACC (Aire contaminado por combustibles)
#
# 15 = DBV (Dieta baja en vegetales)
#
# 16 = BAF (Baja actividad física)
#
# 17 = TAB (Tabaquismo)
#
# 18 = GLU (Glucemia alta)
#
# 19 = CAI (Contaminación del aire)
#
# 20 = IMC (IMC alto)
#
# 21 = FSA (Falta de sanitarios)
#
# 22 = FLA (Falta de lavabos)
#
# 23 = DRO (Drogadicción)
#
# 24 = BDO (Baja densidad ósea)
#
# 25 = AVI (Avitaminosis)
#
# 26 = REC (Retraso en crecimiento)
#
# 27 = LMD (Lactancia materna discontinuada)
#
# 28 = LMN (Lactancia materna no exclusiva)
#
# 29 = DFE (Deficiencia de hierro)

# %%
# Cambio los índices de las columnas
data_2_v1 = data_2.rename(columns={"Code":"COD", "Year":"AÑO","Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)":"CAE","Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)":"HIP","Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)":"DAS","Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)":"DBG","Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)":"ALC","Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)":"DBF","Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: All Ages (Number)":"AGI","Deaths - Cause: All causes - Risk: Secondhand smoke - Sex: Both - Age: All Ages (Number)":"FUP","Deaths - Cause: All causes - Risk: Low birth weight - Sex: Both - Age: All Ages (Number)":"BPN","Deaths - Cause: All causes - Risk: Child wasting - Sex: Both - Age: All Ages (Number)":"DEI","Deaths - Cause: All causes - Risk: Unsafe sex - Sex: Both - Age: All Ages (Number)":"SXI","Deaths - Cause: All causes - Risk: Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)":"DBS","Deaths - Cause: All causes - Risk: Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)":"ACC","Deaths - Cause: All causes - Risk: Diet low in vegetables - Sex: Both - Age: All Ages (Number)":"DBV","Deaths - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)":"BAF","Deaths - Cause: All causes - Risk: Smoking - Sex: Both - Age: All Ages (Number)":"TAB","Deaths - Cause: All causes - Risk: High fasting plasma glucose - Sex: Both - Age: All Ages (Number)":"GLU","Deaths - Cause: All causes - Risk: Air pollution - Sex: Both - Age: All Ages (Number)":"CAI","Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)":"IMC","Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: All Ages (Number)":"FSA","Deaths - Cause: All causes - Risk: No access to handwashing facility - Sex: Both - Age: All Ages (Number)":"FLA","Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)":"DRO","Deaths - Cause: All causes - Risk: Low bone mineral density - Sex: Both - Age: All Ages (Number)":"BDO","Deaths - Cause: All causes - Risk: Vitamin A deficiency - Sex: Both - Age: All Ages (Number)":"AVI","Deaths - Cause: All causes - Risk: Child stunting - Sex: Both - Age: All Ages (Number)":"REC","Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)":"LMD","Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)":"LMN","Deaths - Cause: All causes - Risk: Iron deficiency - Sex: Both - Age: All Ages (Number)":"DFE"})

# %%
# Observamos si las columnas cambiaron
data_2_v1
# Out:
#              COD   AÑO   CAE    HIP   DAS   DBG   ALC   DBF   AGI   FUP  ...  \
# Entity                                                                   ...
# Afghanistan  AFG  1990  3169  25633  1045  7077   356  3185  3702  4794  ...
# Afghanistan  AFG  1991  3222  25872  1055  7149   364  3248  4309  4921  ...
# Afghanistan  AFG  1992  3395  26309  1075  7297   376  3351  5356  5279  ...
# Afghanistan  AFG  1993  3623  26961  1103  7499   389  3480  7152  5734  ...
# Afghanistan  AFG  1994  3788  27658  1134  7698   399  3610  7192  6050  ...
# ...          ...   ...   ...    ...   ...   ...   ...   ...   ...   ...  ...
# Zimbabwe     ZWE  2015  2835  11483  1063  1354  4854  1820  4336  1614  ...
# Zimbabwe     ZWE  2016  2781  11663  1082  1383  4915  1854  4244  1625  ...
# Zimbabwe     ZWE  2017  2700  11819  1098  1409  4992  1883  4193  1625  ...
# Zimbabwe     ZWE  2018  2669  12002  1117  1439  5044  1917  4013  1628  ...
# Zimbabwe     ZWE  2019  2680  12241  1140  1475  5156  1960  3914  1646  ...
#
#               IMC   FSA   FLA   DRO  BDO   AVI    REC  LMD   LMN  DFE
# Entity
# Afghanistan  9518  2798  4825   174  389  2016   7686  107  2216  564
# Afghanistan  9489  3254  5127   188  389  2056   7886  121  2501  611
# Afghanistan  9528  4042  5889   211  393  2100   8568  150  3053  700
# Afghanistan  9611  5392  7007   232  411  2316   9875  204  3726  773
# Afghanistan  9675  5418  7421   247  413  2665  11031  204  3833  812
# ...           ...   ...   ...   ...  ...   ...    ...  ...   ...  ...
# Zimbabwe     5636  2879  4328  1068  407   138    730   21   734  282
# Zimbabwe     5849  2798  4295  1042  415   101    674   20   700  275
# Zimbabwe     6047  2744  4251  1007  424    82    629   19   678  267
# Zimbabwe     6248  2608  4153   969  434    85    607   17   644  261
# Zimbabwe     6475  2531  4113   963  438    81    585   16   631  259
#
# [6840 rows x 30 columns]

# %%
# Veo los datos nulos
data_2_v1.isnull().sum().sum()
# Out:
# 690

# %%
# Son 690, vemos en que columnas están
data_2_v1.isnull().sum()
# Out:
# COD    690
# AÑO      0
# CAE      0
# HIP      0
# DAS      0
# DBG      0
# ALC      0
# DBF      0
# AGI      0
# FUP      0
# BPN      0
# DEI      0
# SXI      0
# DBS      0
# ACC      0
# DBV      0
# BAF      0
# TAB      0
# GLU      0
# CAI      0
# IMC      0
# FSA      0
# FLA      0
# DRO      0
# BDO      0
# AVI      0
# REC      0
# LMD      0
# LMN      0
# DFE      0
# dtype: int64

# %%
# Todos los datos faltantes pertenecen al código de país. ¿Cuáles serán los países?
# Cambiamos los NaN por 1
data_2_v2 = data_2_v1.fillna(1)
# Consultamos dentro de la columna COD el valor 1 para saber que países o zonas son. Se filtra por año para que muestre solamente una vez el país o zona
data_2_v3 = data_2_v2[(data_2_v2['COD']==1) & (data_2_v2['AÑO']==1990)]
data_2_v3['COD']
# Out:
# Entity
# African Region (WHO)                  1
# East Asia & Pacific (WB)              1
# Eastern Mediterranean Region (WHO)    1
# England                               1
# Europe & Central Asia (WB)            1
# European Region (WHO)                 1
# G20                                   1
# Latin America & Caribbean (WB)        1
# Middle East & North Africa (WB)       1
# North America (WB)                    1
# Northern Ireland                      1
# OECD Countries                        1
# Region of the Americas (WHO)          1
# Scotland                              1
# South Asia (WB)                       1
# South-East Asia Region (WHO)          1
# Sub-Saharan Africa (WB)               1
# Wales                                 1
# Western Pacific Region (WHO)          1
# World Bank High Income                1
# World Bank Low Income                 1
# World Bank Lower Middle Income        1
# World Bank Upper Middle Income        1
# Name: COD, dtype: object

# %%
# Son 23 países o zonas que tienen originalmente el COD el valor NaN
data_2_v2.loc[data_2_v2["COD"] == "African Region (WHO)", ] = 0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-477e61712437> in <cell line: 2>()
#       1 # Son 23 países o zonas que tienen originalmente el COD el valor NaN
# ----> 2 data_2_v2.loc[data_2_v2["COD"] == "African Region (WHO)", ] = 0
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     847
#     848         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849         iloc._setitem_with_indexer(indexer, value, self.name)
#     850
#     851     def _validate_key(self, key, axis: AxisInt):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1833         if take_split_path:
#    1834             # We have to operate column-wise
# -> 1835             self._setitem_with_indexer_split_path(indexer, value, name)
#    1836         else:
#    1837             self._setitem_single_block(indexer, value, name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1857
#    1858         # Ensure we have something we can iterate over
# -> 1859         info_axis = indexer[1]
#    1860         ilocs = self._ensure_iterable_column_indexer(info_axis)
#    1861
#
# IndexError: tuple index out of range
