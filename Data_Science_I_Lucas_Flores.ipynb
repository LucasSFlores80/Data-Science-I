# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasSFlores80/Data-Science-I/blob/main/Data_Science_I_Lucas_Flores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Selección de Datasets**
# Opción 1: Producción de Carne Bovina en Argentina.
# Variables a estudiar: Producción o cabezas de ganado por provincia, departamentos. Se puede estudiar la eficiencia del cuidado del ganado, los costos de producción y mantenimiento, etc.
# Archivo: produccion-de-carne-bovina.csv (23 columnas, 2599 filas)
# Fuente: https://www.kaggle.com/datasets/anggyelarez/produccin-de-carne-bovina-en-argentina
#
# Opción 2: Número de Muertes por Factores de Riesgo en el mundo.
# Variables a estudiar: Mayor incidencia de muertes por factor, por país y año, mayores factores de riesgo de muerte en el mundo por año, factores de riesgo por año, continentes o zonas (américa latina, norteamérica, etc).
# De acuerdo a esos factores de riesgo poder predecir por país o zona geográfica estrategias para su disminución (¿o me estoy adelantando?)
# Archivo: number-of-deaths-by-risk-factor.csv (31 columnas, 6841 filas)
# Fuente: https://www.kaggle.com/datasets/muhammadumairab/number-of-deaths-by-risk-factor
#
# Opción 3: Número de Escuelas en la República Argentina.
# Variables a estudiar: Cantidad de escuelas por provincia, por departamento. Tipos de escuela (bachiller, técnica, etc). Se puede hacer un estudio del tipo de institución de acuerdo al desarrollo económico de la zona.
# (por ejemplo en Bariloche está Centro Atómico e INVAP y poca oferta de escuelas técnicas). Habría que asociar este csv con otro que contenga la información de los tipos de industrias, empleos o desarrollo económico de las distintas zonas
# Archivo: escuelas.csv (25 columnas, 63095 filas)
# Fuente: https://www.kaggle.com/datasets/correntino/escuelas-argentinas

# %%
import pandas as pd

# %% [markdown]
# ### Dataset 1

# %%
url = 'https://raw.githubusercontent.com/LucasSFlores80/Data-Science-I/main/produccion-de-carne-bovina.csv'
data_1 = pd.read_csv(url, index_col=0, encoding='latin-1')
data_1
# Out:
#               pais  provincia_id            provincia  departamento_id  \
# pais_id
# 32       Argentina             6         Buenos Aires              105
# 32       Argentina             6         Buenos Aires              231
# 32       Argentina             6         Buenos Aires              203
# 32       Argentina            14              Cordoba               42
# 32       Argentina            14              Cordoba               56
# ...            ...           ...                  ...              ...
# 32       Argentina            86  Santiago Del Estero              168
# 32       Argentina            86  Santiago Del Estero              175
# 32       Argentina            86  Santiago Del Estero              182
# 32       Argentina            86  Santiago Del Estero              189
# 32       Argentina             6         Buenos Aires              466
#
#                departamento  prov_depto   año  mes  \
# pais_id
# ...

# %% [markdown]
# Dataset 2

# %%
url = 'https://raw.githubusercontent.com/LucasSFlores80/Data-Science-I/main/number-of-deaths-by-risk-factor.csv'
data_2 = pd.read_csv(url, index_col=0)
data_2
# Out:
#             Code  Year  \
# Entity
# Afghanistan  AFG  1990
# Afghanistan  AFG  1991
# Afghanistan  AFG  1992
# Afghanistan  AFG  1993
# Afghanistan  AFG  1994
# ...          ...   ...
# Zimbabwe     ZWE  2015
# Zimbabwe     ZWE  2016
# Zimbabwe     ZWE  2017
# Zimbabwe     ZWE  2018
# Zimbabwe     ZWE  2019
#
#              Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                               3169
# Afghanistan                                               3222
# Afghanistan                                               3395
# Afghanistan                                               3623
# Afghanistan                                               3788
# ...                                                        ...
# Zimbabwe                                                  2835
# Zimbabwe                                                  2781
# ...

# %% [markdown]
# Dataset 3

# %%
url = 'https://raw.githubusercontent.com/LucasSFlores80/Data-Science-I/main/escuelas.csv'
data_3 = pd.read_csv(url, index_col=0, encoding='latin-1')
data_3
# Out:
#               CUE Anexo                                             Nombre  \
# Jurisdicción
# Buenos Aires   60000100          JARDÍN DE INFANTES Nº915 JAVIER VILLAFAÑE
# Buenos Aires   60000200  ESCUELA DE EDUCACIÓN PRIMARIA Nº2 DOMINGO FAUS...
# Buenos Aires   60000300                        INSTITUTO PEDRO B. PALACIOS
# Buenos Aires   60000400                      INSTITUTO JUANA DE IBARBOUROU
# Buenos Aires   60000600                         ESCUELA DE TEATRO DE MORON
# ...                 ...                                                ...
# Tucumán       909000500              ESCUELA DE AGRICULTURA Y SACAROTECNIA
# Tucumán       909000600  ESC. DE BELLAS ARTES Y ARTES DECOR. E INDUS. A...
# Tucumán       909000700                           INST. SUPERIOR DE MUSICA
# Tucumán       909000800                     INSTITUTO TECNICO DE AGUILARES
# Tucumán       909000900  ESC. TECNICA N° 3 DE VIALIDAD NACIONAL GRAL. M...
#
#                Sector  Ámbito  \
# Jurisdicción
# ...
